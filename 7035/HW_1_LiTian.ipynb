# %% [markdown]
# 1. Write a Python program with function to sum of two given integers. However, if the sum is between 15 to 20 it will return 20.
#
# For example:
#
# if a=10, b =6, it will return 20
#
# if a=10, b=2, it will return 12
#
# if a=10, b=2, it will return 22
#
# DONOT PRINT IN THE FUNCTION.

# %%
def sum(x, y):
    #Write your code below
    sum_num = x + y
    if  20 > sum_num > 15:
        return 20
    return sum_num


print(sum(10, 6))
print(sum(10, 2))
print(sum(10, 12))
# Out:
# 20
# 12
# 22

# %% [markdown]
# 2. Please transfer the following equation into Python
# $y=\sqrt{(a-b)^2+(a+b)^2}$.
#
# You can use a function in math library for sqrt
# #DO NOT PRINT IN THE FUNCTION!!

# %%
import math
def ED(a, b):
##Please write your code below
    return math.sqrt(math.pow((a-b),2) + math.pow((a+b),2))

print(ED(3, 5))
print(ED(7, 8))
print(ED(8, 9))
# Out:
# 8.246211251235321
# 15.033296378372908
# 17.029386365926403

# %% [markdown]
# 3. Write a Python program to check if a number is positive, negative or zero.
# Hint: if elif else
#
# num is provided in the first line using input("Input a number"). You can input any numbers you like.

# %%
num = float(input("Input a number: "))
check_num(num)
##Write your code with if elif else below
def check_num(this_num):
    trans_num = int(this_num)
    if trans_num >0:
        print('positive')
    elif trans_num <0:
        print('negative')
    else:
        print('zero')
# Out:
# Input a number: -1
# negative

# %% [markdown]
# 4. Write a Python program to calculate the sum of three given numbers, if the values of each number are equal then return thrice of their sum else please return their sum directly.
#
# For example,
#
# if x = 3, y = 3, z = 3, return 27
#
# if x = 1, y = 2, z = 3, return 6

# %%
def sum_thrice(x, y, z):
    if x == y and x == z and y==z:
        return x**3
    return x+y+z

print(sum_thrice(1, 2, 3))
print(sum_thrice(0, 4, 5))
print(sum_thrice(3, 3, 3))
# Out:
# 6
# 9
# 27

# %% [markdown]
# 5. Write a Python program to find whether a given number is even or odd, print out an appropriate message to users.
#
# For example:
#
# if the number is even, print "The number is even" otherwise print "The number is odd"

# %%
def judgenum(num):
    if num % 2 == 0:
        print('The number is even')
    else:
        print('The number is odd')
judgenum(1)
judgenum(2)
judgenum(3)
# Out:
# The number is odd
# The number is even
# The number is odd

# %% [markdown]
# 6. Write a Python program to get the volume of a sphere with given radius values.
# The volume of the sphere is : $V = 4/3 × π × r^3$.
# DONOT PRINT IN FUNCTION

# %%
import math

def volume(radius):
  ##show your codes
    return 4/3*math.pi*radius**3

print(volume(4))
print(volume(5))
##PLEASE ENSURE THAT YOUR RESULTS ARE DISPLAYED BY PRINT HERE.
# Out:
# 268.082573106329
# 523.5987755982989

# %% [markdown]
# 7. Write a Python program to append list1 to list2.

# %%
list1 = [1, 2, 3, 0]
list2 = ['Red', 'Green', 'Black']
##Write your code blew and rember to display them
list3 = [list1,list2]

list1_copy = list1.copy()
for e in list2:
    list1_copy.append(e)
    
print(list3)
print(list1_copy)
# Out:
# [[1, 2, 3, 0], ['Red', 'Green', 'Black']]
# [1, 2, 3, 0, 'Red', 'Green', 'Black']

# %% [markdown]
# 8. Write a Python program to get the largest number from a list.
#
# For example:
# We can use max([1,2,3]) to get the largest number of a list. Now, please do not use max() and write a fuction for this purpose yourself.
#
#
# Requirements:
#
# a. Donot use max(a list) to get the largest number, otherwise you can only get the minimum point.
#
# b. Donot print the value inside the function. Just return them.

# %%
def max_num_in_list( list ):
    max_num = list[0]
    for e in list:
        if e > max_num:
            max_num = e
    return max_num
print(max_num_in_list([1, 2, -8, 0]))
print(max_num_in_list([3, 3, -1, 1]))
# Out:
# 2
# 3

# %% [markdown]
# 9. Write a Python program to sum all the items in a list.
#
# For a list [1, 2, -8], we can use sum([1, 2, -8]) for this purpose.
# Now, donot use sum(). Write this function yourself.

# %%
def sum_list(items):
    sum_num = 0
    for e in items:
        sum_num+=e
    return sum_num

print(sum_list([1,2,-8]))
print(sum_list([3,2,-8]))
# Out:
# -5
# -3

# %% [markdown]
# 10. Write a Python program to get a string from a given string where all occurrences of its first char have been changed to '$', except the first char itself.
#
#
# ![image.png](data:image/png;base64,...)

# %%
def change_char(str1):
    f_char = str1[0]
    return f_char + str1.replace(f_char, '$')[1:]

print(change_char('restart'))
# Out:
# resta$t

# %% [markdown]
# 11.Write a Python program to remove the characters which have odd index values of a given string.
#
# ![image.png](data:image/png;base64,...)

# %%
def odd_values_string(str):
    new_str = ""
    for i in range(len(str)):
        if i % 2 != 0:
            new_str += str[i]
    return new_str
print(odd_values_string('abcdef'))
print(odd_values_string('python'))
# Out:
# bdf
# yhn
